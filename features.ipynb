# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("raw_data.csv")
df.head()
# Out:
#   team  season name team.1    position situation  games_played  \
# 0  MIN    2008  MIN    MIN  Team Level     other            82
# 1  MIN    2008  MIN    MIN  Team Level       all            82
# 2  MIN    2008  MIN    MIN  Team Level      5on5            82
# 3  MIN    2008  MIN    MIN  Team Level      4on5            82
# 4  MIN    2008  MIN    MIN  Team Level      5on4            82
#
#    xGoalsPercentage  corsiPercentage  fenwickPercentage   iceTime  xOnGoalFor  \
# 0              0.48             0.49               0.49   11901.0      143.97
# 1              0.48             0.48               0.48  299195.0     2210.01
# 2              0.46             0.47               0.47  230258.0     1602.93
# 3              0.13             0.12               0.14   28293.0       65.18
# 4              0.88             0.88               0.86   28743.0      397.93
#
#    xGoalsFor  xReboundsFor  xFreezeFor  xPlayStoppedFor  \
# 0      20.06         10.29       28.65             4.91
# 1     188.02        148.38      496.23            72.10
# 2     115.06         99.67      378.61            52.00
# 3       6.20          2.96        8.25             1.84
# 4      46.71         35.46       80.72            13.34
#
#    xPlayContinuedInZoneFor  xPlayContinuedOutsideZoneFor  \
# 0                    86.83                         54.71
# 1                  1266.33                        955.62
# 2                   906.46                        715.85
# 3                    19.26                         50.60
# 4                   253.78                        134.45
#
#    flurryAdjustedxGoalsFor  scoreVenueAdjustedxGoalsFor  \
# 0                    18.49                        20.06
# 1                   182.46                       188.50
# 2                   112.73                       115.53
# 3                     6.03                         6.20
# 4                    45.21                        46.71
#
#    flurryScoreVenueAdjustedxGoalsFor  shotsOnGoalFor  missedShotsFor  \
# 0                              18.49           154.0            58.0
# 1                             182.94          2258.0           907.0
# 2                             113.21          1630.0           661.0
# 3                               6.03            67.0            24.0
# 4                              45.21           407.0           164.0
#
#    blockedShotAttemptsFor  shotAttemptsFor  goalsFor  reboundsFor  \
# 0                    61.0            273.0      26.0          9.0
# 1                   982.0           4147.0     214.0        131.0
# 2                   729.0           3020.0     122.0         84.0
# 3                    11.0            102.0       8.0          6.0
# 4                   181.0            752.0      58.0         32.0
#
#    reboundGoalsFor  freezeFor  playStoppedFor  playContinuedInZoneFor  \
# 0              1.0       33.0             2.0                    77.0
# 1             25.0      446.0            42.0                   996.0
# 2             12.0      344.0            26.0                   702.0
# 3              2.0        7.0             0.0                    10.0
# 4             10.0       62.0            14.0                   207.0
#
#    playContinuedOutsideZoneFor  savedShotsOnGoalFor  \
# 0                         65.0                128.0
# 1                       1336.0               2044.0
# 2                       1013.0               1508.0
# 3                         60.0                 59.0
# 4                        198.0                349.0
#
#    savedUnblockedShotAttemptsFor  penaltiesFor  penalityMinutesFor  \
# 0                          186.0           8.0                16.0
# 1                         2951.0         353.0               847.0
# 2                         2169.0         303.0               736.0
# 3                           83.0          21.0                53.0
# 4                          513.0          21.0                42.0
#
#    faceOffsWonFor  hitsFor  takeawaysFor  giveawaysFor  lowDangerShotsFor  \
# 0           139.0     43.0          19.0          22.0              143.0
# 1          2223.0   1468.0         440.0         630.0             2489.0
# 2          1554.0   1319.0         351.0         490.0             1873.0
# 3           242.0     64.0          56.0          37.0               64.0
# 4           288.0     42.0          14.0          81.0              409.0
#
#    mediumDangerShotsFor  highDangerShotsFor  lowDangerxGoalsFor  \
# 0                  53.0                16.0                5.35
# 1                 529.0               147.0               72.78
# 2                 355.0                63.0               55.44
# 3                  18.0                 9.0                1.86
# 4                 103.0                59.0               10.13
#
#    mediumDangerxGoalsFor  highDangerxGoalsFor  lowDangerGoalsFor  \
# 0                   6.50                 8.21                6.0
# 1                  62.15                53.09               74.0
# 2                  41.54                18.07               60.0
# 3                   2.09                 2.24                2.0
# 4                  12.02                24.55                6.0
#
#    mediumDangerGoalsFor  highDangerGoalsFor  scoreAdjustedShotsAttemptsFor  \
# 0                   8.0                12.0                         273.00
# 1                  76.0                64.0                        4158.28
# 2                  47.0                15.0                        3031.28
# 3                   2.0                 4.0                         102.00
# 4                  19.0                33.0                         752.00
#
#    unblockedShotAttemptsFor  scoreAdjustedUnblockedShotAttemptsFor  \
# 0                     212.0                                 212.00
# 1                    3165.0                                3172.77
# 2                    2291.0                                2298.77
# 3                      91.0                                  91.00
# 4                     571.0                                 571.00
#
#    dZoneGiveawaysFor  xGoalsFromxReboundsOfShotsFor  \
# 0               12.0                           2.95
# 1              307.0                          33.23
# 2              257.0                          20.39
# 3               30.0                           0.68
# 4                8.0                           9.21
#
#    xGoalsFromActualReboundsOfShotsFor  reboundxGoalsFor  totalShotCreditFor  \
# 0                                1.16              1.16               21.46
# 1                               23.91             24.10              194.59
# 2                               15.72             15.88              118.00
# 3                                1.12              1.12                5.62
# 4                                5.92              5.95               49.51
#
#    scoreAdjustedTotalShotCreditFor  scoreFlurryAdjustedTotalShotCreditFor  \
# 0                            21.46                                  19.80
# 1                           195.04                                 190.90
# 2                           118.45                                 117.10
# 3                             5.62                                   5.61
# 4                            49.51                                  48.39
#
#    xOnGoalAgainst  xGoalsAgainst  xReboundsAgainst  xFreezeAgainst  \
# 0          140.35          21.66             10.52           27.10
# 1         2424.40         202.35            163.50          557.44
# 2         1813.85         132.79            113.02          436.30
# 3          404.67          41.63             37.02           85.07
# 4           65.53           6.28              2.93            8.95
#
#    xPlayStoppedAgainst  xPlayContinuedInZoneAgainst  \
# 0                 4.72                        81.06
# 1                78.38                      1366.67
# 2                58.34                      1009.24
# 3                13.41                       256.88
# 4                 1.92                        19.50
#
#    xPlayContinuedOutsideZoneAgainst  flurryAdjustedxGoalsAgainst  \
# 0                             54.25                        20.69
# 1                           1032.29                       195.74
# 2                            789.79                       129.67
# 3                            138.45                        39.20
# 4                             49.80                         6.17
#
#    scoreVenueAdjustedxGoalsAgainst  flurryScoreVenueAdjustedxGoalsAgainst  \
# 0                            21.66                                  20.69
# 1                           201.98                                 195.38
# 2                           132.41                                 129.31
# 3                            41.63                                  39.20
# 4                             6.28                                   6.17
#
#    shotsOnGoalAgainst  missedShotsAgainst  blockedShotAttemptsAgainst  \
# 0               158.0                60.0                        67.0
# 1              2518.0               949.0                      1033.0
# 2              1867.0               708.0                       802.0
# 3               417.0               162.0                       156.0
# 4                76.0                19.0                         8.0
#
#    shotAttemptsAgainst  goalsAgainst  reboundsAgainst  reboundGoalsAgainst  \
# 0                285.0          28.0             11.0                  4.0
# 1               4500.0         197.0            146.0                 29.0
# 2               3377.0         136.0             96.0                 18.0
# 3                735.0          27.0             33.0                  7.0
# 4                103.0           6.0              6.0                  0.0
#
#    freezeAgainst  playStoppedAgainst  playContinuedInZoneAgainst  \
# 0           30.0                 4.0                        85.0
# 1          619.0                60.0                      1112.0
# 2          462.0                48.0                       796.0
# 3          113.0                 5.0                       216.0
# 4           14.0                 3.0                        15.0
#
#    playContinuedOutsideZoneAgainst  savedShotsOnGoalAgainst  \
# 0                             60.0                    130.0
# 1                           1333.0                   2321.0
# 2                           1037.0                   1731.0
# 3                            185.0                    390.0
# 4                             51.0                     70.0
#
#    savedUnblockedShotAttemptsAgainst  penaltiesAgainst  \
# 0                              190.0              15.0
# 1                             3270.0             394.0
# 2                             2439.0             326.0
# 3                              552.0              28.0
# 4                               89.0              25.0
#
#    penalityMinutesAgainst  faceOffsWonAgainst  hitsAgainst  takeawaysAgainst  \
# 0                    34.0               159.0         39.0              17.0
# 1                   919.0              2361.0       1443.0             443.0
# 2                   776.0              1684.0       1301.0             345.0
# 3                    59.0               290.0         34.0              12.0
# 4                    50.0               228.0         69.0              69.0
#
#    giveawaysAgainst  lowDangerShotsAgainst  mediumDangerShotsAgainst  \
# 0              26.0                  149.0                      46.0
# 1             582.0                 2724.0                     587.0
# 2             456.0                 2079.0                     420.0
# 3              71.0                  425.0                     105.0
# 4              29.0                   71.0                      16.0
#
#    highDangerShotsAgainst  lowDangerxGoalsAgainst  mediumDangerxGoalsAgainst  \
# 0                    23.0                    5.47                       5.58
# 1                   156.0                   81.42                      68.54
# 2                    76.0                   62.83                      48.89
# 3                    49.0                   11.07                      12.11
# 4                     8.0                    2.06                       1.95
#
#    highDangerxGoalsAgainst  lowDangerGoalsAgainst  mediumDangerGoalsAgainst  \
# 0                    10.61                   10.0                       2.0
# 1                    52.39                   70.0                      70.0
# 2                    21.06                   55.0                      64.0
# 3                    18.45                    3.0                       2.0
# 4                     2.27                    2.0                       2.0
#
#    highDangerGoalsAgainst  scoreAdjustedShotsAttemptsAgainst  \
# 0                    16.0                             285.00
# 1                    57.0                            4490.31
# 2                    17.0                            3367.31
# 3                    22.0                             735.00
# 4                     2.0                             103.00
#
#    unblockedShotAttemptsAgainst  scoreAdjustedUnblockedShotAttemptsAgainst  \
# 0                         218.0                                     218.00
# 1                        3467.0                                    3459.72
# 2                        2575.0                                    2567.72
# 3                         579.0                                     579.00
# 4                          95.0                                      95.00
#
#    dZoneGiveawaysAgainst  xGoalsFromxReboundsOfShotsAgainst  \
# 0                    7.0                               3.09
# 1                  257.0                              36.30
# 2                  221.0                              23.18
# 3                    1.0                               9.34
# 4                   28.0                               0.69
#
#    xGoalsFromActualReboundsOfShotsAgainst  reboundxGoalsAgainst  \
# 0                                    2.24                  2.22
# 1                                   27.99                 29.58
# 2                                   17.52                 18.56
# 3                                    7.21                  7.36
# 4                                    1.02                  1.43
#
#    totalShotCreditAgainst  scoreAdjustedTotalShotCreditAgainst  \
# 0                   21.35                                21.35
# 1                  204.64                               204.38
# 2                  134.99                               134.73
# 3                   43.14                                43.14
# 4                    5.15                                 5.15
#
#    scoreFlurryAdjustedTotalShotCreditAgainst  penalitiesFor  \
# 0                                      20.46            NaN
# 1                                     200.25            NaN
# 2                                     133.06            NaN
# 3                                      41.59            NaN
# 4                                       5.14            NaN
#
#    penalitiesAgainst  playoff
# 0                NaN        0
# 1                NaN        0
# 2                NaN        0
# 3                NaN        0
# 4                NaN        0

# %%
df = df[df["situation"]== "all"]
df.shape
# Out:
# (554, 110)

# %%
df["xOnGoalFor"]
# Out:
# 1       2210.01
# 6       2386.17
# 11      2187.76
# 16      2448.00
# 21      2207.19
#          ...
# 2746    1351.06
# 2751    1534.80
# 2756    1244.75
# 2761    1273.22
# 2766    1299.98
# Name: xOnGoalFor, Length: 554, dtype: float64

# %%
def engineer_features(df):
    df = df.copy()
    df["xOnGoalFor_PerGame"] = df["xOnGoalFor"] / df["games_played"]
    df["xPlayContinuedInZoneFor_PerGame"] = df["xPlayContinuedInZoneFor"] / df["games_played"]
    df["xPlayContinuedOutsideZoneFor_PerGame"] = df["xPlayContinuedOutsideZoneFor"] / df["games_played"]
    df["xPlayContinuedInZoneAgainst_PerGame"] = df["xPlayContinuedInZoneAgainst"] / df["games_played"]
    df["xPlayContinuedOutsideZoneAgainst_PerGame"] = df["xPlayContinuedOutsideZoneAgainst"] / df["games_played"]
    df["flurryScoreVenueAdjustedxGoalsFor_PerGame"] = df["flurryScoreVenueAdjustedxGoalsFor"] / df["games_played"]
    df["lowDangerShotsFor_PerGame"] = df["lowDangerShotsFor"] / df["games_played"]
    df["lowDangerxGoalsFor_PerGame"] = df["lowDangerxGoalsFor"] / df["games_played"]
    df["lowDangerGoalsFor_PerGame"] = df["lowDangerGoalsFor"] / df["games_played"]
    df["lowDangerShotsAgainst_PerGame"] = df["lowDangerShotsAgainst"] / df["games_played"]
    df["lowDangerxGoalsAgainst_PerGame"] = df["lowDangerxGoalsAgainst"] / df["games_played"]
    df["lowDangerGoalsAgainst_PerGame"] = df["lowDangerGoalsAgainst"] / df["games_played"]
    
    df = df[["season",
             "corsiPercentage",
             "fenwickPercentage",
             "xGoalsPercentage",
             "xOnGoalFor_PerGame",
             "xPlayContinuedInZoneFor_PerGame",
             "xPlayContinuedOutsideZoneFor_PerGame",
             "xPlayContinuedInZoneAgainst_PerGame",
             "xPlayContinuedOutsideZoneAgainst_PerGame",
             "flurryScoreVenueAdjustedxGoalsFor_PerGame",
             "lowDangerShotsFor_PerGame",
             "lowDangerxGoalsFor_PerGame",
             "lowDangerGoalsFor_PerGame",
             "lowDangerShotsAgainst_PerGame",
             "lowDangerxGoalsAgainst_PerGame",
             "lowDangerGoalsAgainst_PerGame",
             "playoff"]]
    return df

# %%
df = engineer_features(df)
df.shape
# Out:
# (554, 17)

# %%
df.head()
# Out:
#     season  corsiPercentage  fenwickPercentage  xGoalsPercentage  \
# 1     2008             0.48               0.48              0.48
# 6     2008             0.50               0.50              0.51
# 11    2008             0.46               0.47              0.47
# 16    2008             0.51               0.51              0.51
# 21    2008             0.47               0.48              0.49
#
#     xOnGoalFor_PerGame  xPlayContinuedInZoneFor_PerGame  \
# 1            26.951341                        15.443049
# 6            29.458889                        16.346296
# 11           27.009383                        15.300123
# 16           29.853659                        17.133659
# 21           26.916951                        14.914756
#
#     xPlayContinuedOutsideZoneFor_PerGame  xPlayContinuedInZoneAgainst_PerGame  \
# 1                              11.653902                            16.666707
# 6                              12.585556                            15.995185
# 11                             11.586049                            17.462346
# 16                             12.453171                            16.105000
# 21                             11.198171                            15.753659
#
#     xPlayContinuedOutsideZoneAgainst_PerGame  \
# 1                                  12.588902
# 6                                  12.556420
# 11                                 13.736173
# 16                                 11.953659
# 21                                 12.303780
#
#     flurryScoreVenueAdjustedxGoalsFor_PerGame  lowDangerShotsFor_PerGame  \
# 1                                    2.230976                  30.353659
# 6                                    2.693704                  30.901235
# 11                                   2.328889                  30.222222
# 16                                   2.633780                  32.365854
# 21                                   2.378659                  29.646341
#
#     lowDangerxGoalsFor_PerGame  lowDangerGoalsFor_PerGame  \
# 1                     0.887561                   0.902439
# 6                     0.864815                   1.086420
# 11                    0.872346                   0.790123
# 16                    0.964146                   0.719512
# 21                    0.936951                   0.780488
#
#     lowDangerShotsAgainst_PerGame  lowDangerxGoalsAgainst_PerGame  \
# 1                       33.219512                        0.992927
# 6                       30.913580                        0.878395
# 11                      35.012346                        1.011111
# 16                      31.109756                        0.936951
# 21                      32.390244                        0.998293
#
#     lowDangerGoalsAgainst_PerGame  playoff
# 1                        0.853659        0
# 6                        0.691358        1
# 11                       0.876543        0
# 16                       0.865854        0
# 21                       1.073171        0

# %%
df.to_csv("starting_data.csv", index=False)
