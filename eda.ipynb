# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from sklearn.compose import make_column_transformer
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_validate, train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from scipy.stats import randint, loguniform

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
dfs = []
for f in Path("data").iterdir():
    df = pd.read_csv(f)
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

# %%
df = df[df["games_played"] == 82]

# %%
df.shape
# Out:
# (2110, 109)

# %%
int_cols = df.select_dtypes(include="int64").columns.tolist()
int_cols
# Out:
# ['season', 'games_played']

# %%
obj_cols = df.select_dtypes(include="object").columns.tolist()
obj_cols
# Out:
# ['team', 'name', 'team.1', 'position', 'situation']

# %%
columns_to_drop = int_cols + obj_cols

# %%
df.to_csv("raw_data.csv", index=False)

# %%
df_x = pd.read_excel("lol.xlsx")    
df_x.to_csv("lol.csv", index=False)

# %%
df_pts = pd.read_csv("lol.csv")
df_pts.head()
# Out:
#   team  season  playoff
# 0  NYI    2009        0
# 1  ANA    2009        0
# 2  CGY    2009        0
# 3  EDM    2009        0
# 4  CBJ    2009        0

# %%
df = df.merge(
    df_pts, 
    on=["team", "season"],
    how="left"
)

# %%
missing_col = df.columns[df.isna().any()].tolist()
missing_col
# Out:
# ['penaltiesFor', 'penaltiesAgainst', 'penalitiesFor', 'penalitiesAgainst']

# %%
columns_to_drop += missing_col
columns_to_drop
# Out:
# ['season',
#  'games_played',
#  'team',
#  'name',
#  'team.1',
#  'position',
#  'situation',
#  'penaltiesFor',
#  'penaltiesAgainst',
#  'penalitiesFor',
#  'penalitiesAgainst']

# %%
df = df[df["situation"] == "all"]

# %%
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#     xGoalsPercentage  corsiPercentage  fenwickPercentage   iceTime  \
# 1               0.50             0.48               0.49  300913.0
# 6               0.46             0.48               0.47  299752.0
# 11              0.50             0.51               0.50  298794.0
# 16              0.45             0.45               0.45  299826.0
# 21              0.47             0.48               0.47  299841.0
#
#     xOnGoalFor  xGoalsFor  xReboundsFor  xFreezeFor  xPlayStoppedFor  \
# 1      2466.97     238.16        172.96      545.72            81.21
# 6      2342.95     218.89        161.52      513.90            75.09
# 11     2379.63     201.14        156.39      544.08            75.75
# 16     2306.81     218.63        156.37      515.06            73.47
# 21     2216.25     186.35        151.05      495.89            71.77
#
#     xPlayContinuedInZoneFor  xPlayContinuedOutsideZoneFor  \
# 1                   1348.68                       1056.27
# 6                   1313.28                       1009.26
# 11                  1331.73                       1013.27
# 16                  1263.61                        945.65
# 21                  1252.75                        930.52
#
#     flurryAdjustedxGoalsFor  scoreVenueAdjustedxGoalsFor  \
# 1                    228.49                       238.01
# 6                    211.93                       219.20
# 11                   194.96                       202.33
# 16                   211.61                       217.36
# 21                   180.72                       186.01
#
#     flurryScoreVenueAdjustedxGoalsFor  shotsOnGoalFor  missedShotsFor  \
# 1                              228.35          2494.0           949.0
# 6                              212.23          2471.0           949.0
# 11                             196.15          2351.0          1005.0
# 16                             210.34          2321.0           892.0
# 21                             180.36          2338.0           755.0
#
#     blockedShotAttemptsFor  shotAttemptsFor  goalsFor  reboundsFor  \
# 1                   1182.0           4625.0     214.0        201.0
# 6                    941.0           4361.0     233.0        162.0
# 11                  1216.0           4572.0     201.0        133.0
# 16                  1030.0           4243.0     206.0        171.0
# 21                   960.0           4053.0     214.0        155.0
#
#     reboundGoalsFor  freezeFor  playStoppedFor  playContinuedInZoneFor  \
# 1              38.0      577.0            74.0                  1047.0
# 6              43.0      530.0            68.0                  1081.0
# 11             31.0      529.0            66.0                  1023.0
# 16             49.0      479.0            80.0                  1039.0
# 21             36.0      350.0            86.0                  1020.0
#
#     playContinuedOutsideZoneFor  savedShotsOnGoalFor  \
# 1                        1330.0               2280.0
# 6                        1346.0               2238.0
# 11                       1404.0               2150.0
# 16                       1238.0               2115.0
# 21                       1268.0               2124.0
#
#     savedUnblockedShotAttemptsFor  penalityMinutesFor  faceOffsWonFor  \
# 1                          3229.0               858.0          2261.0
# 6                          3187.0              1187.0          2187.0
# 11                         3155.0              1079.0          2237.0
# 16                         3007.0              1003.0          2170.0
# 21                         2879.0              1020.0          2324.0
#
#     hitsFor  takeawaysFor  giveawaysFor  lowDangerShotsFor  \
# 1    1829.0         948.0         809.0             2521.0
# 6    2050.0         447.0         633.0             2624.0
# 11   1708.0         580.0         724.0             2666.0
# 16   1566.0         544.0        1055.0             2370.0
# 21   2075.0         396.0         387.0             2420.0
#
#     mediumDangerShotsFor  highDangerShotsFor  lowDangerxGoalsFor  \
# 1                  684.0               238.0               74.34
# 6                  625.0               171.0               83.32
# 11                 507.0               183.0               73.96
# 16                 619.0               224.0               70.06
# 21                 521.0               152.0               65.62
#
#     mediumDangerxGoalsFor  highDangerxGoalsFor  lowDangerGoalsFor  \
# 1                   82.03                81.79               79.0
# 6                   75.26                60.31               82.0
# 11                  62.47                64.70               80.0
# 16                  75.73                72.84               62.0
# 21                  62.69                58.04               77.0
#
#     mediumDangerGoalsFor  highDangerGoalsFor  scoreAdjustedShotsAttemptsFor  \
# 1                   65.0                70.0                        4610.42
# 6                   80.0                71.0                        4374.69
# 11                  57.0                64.0                        4596.88
# 16                  62.0                82.0                        4187.18
# 21                  74.0                63.0                        4022.61
#
#     unblockedShotAttemptsFor  scoreAdjustedUnblockedShotAttemptsFor  \
# 1                     3443.0                                3439.86
# 6                     3420.0                                3423.45
# 11                    3356.0                                3375.81
# 16                    3213.0                                3179.05
# 21                    3093.0                                3081.56
#
#     dZoneGiveawaysFor  xGoalsFromxReboundsOfShotsFor  \
# 1               407.0                          38.45
# 6               276.0                          36.01
# 11              387.0                          34.31
# 16              706.0                          34.84
# 21              193.0                          33.40
#
#     xGoalsFromActualReboundsOfShotsFor  reboundxGoalsFor  totalShotCreditFor  \
# 1                                45.78             47.23              229.38
# 6                                31.55             31.89              214.60
# 11                               30.75             32.21              200.95
# 16                               39.76             41.22              209.57
# 21                               32.58             33.37              186.13
#
#     scoreAdjustedTotalShotCreditFor  scoreFlurryAdjustedTotalShotCreditFor  \
# 1                            229.45                                 223.40
# 6                            215.12                                 210.31
# 11                           201.88                                 197.52
# 16                           208.03                                 204.40
# 21                           185.65                                 182.42
#
#     xOnGoalAgainst  xGoalsAgainst  xReboundsAgainst  xFreezeAgainst  \
# 1          2578.49         242.24            181.31          573.57
# 6          2622.30         259.16            182.73          577.49
# 11         2344.66         203.81            158.95          533.19
# 16         2756.37         262.28            190.63          616.39
# 21         2461.70         205.94            166.84          552.75
#
#     xPlayStoppedAgainst  xPlayContinuedInZoneAgainst  \
# 1                 84.06                      1446.29
# 6                 86.50                      1488.61
# 11                76.85                      1330.33
# 16                88.84                      1543.56
# 21                79.93                      1400.65
#
#     xPlayContinuedOutsideZoneAgainst  flurryAdjustedxGoalsAgainst  \
# 1                            1110.53                       231.91
# 6                            1088.63                       243.45
# 11                            994.68                       195.86
# 16                           1138.65                       251.09
# 21                           1039.88                       199.50
#
#     scoreVenueAdjustedxGoalsAgainst  flurryScoreVenueAdjustedxGoalsAgainst  \
# 1                            243.26                                 232.90
# 6                            259.47                                 243.73
# 11                           203.29                                 195.33
# 16                           265.20                                 253.92
# 21                           206.74                                 200.30
#
#     shotsOnGoalAgainst  missedShotsAgainst  blockedShotAttemptsAgainst  \
# 1               2619.0              1019.0                      1379.0
# 6               2737.0              1091.0                       943.0
# 11              2372.0               966.0                      1062.0
# 16              2717.0              1157.0                      1305.0
# 21              2515.0               931.0                      1029.0
#
#     shotAttemptsAgainst  goalsAgainst  reboundsAgainst  reboundGoalsAgainst  \
# 1                5017.0         258.0            166.0                 41.0
# 6                4771.0         243.0            203.0                 39.0
# 11               4400.0         203.0            160.0                 43.0
# 16               5179.0         278.0            183.0                 41.0
# 21               4475.0         249.0            153.0                 40.0
#
#     freezeAgainst  playStoppedAgainst  playContinuedInZoneAgainst  \
# 1           660.0                99.0                      1161.0
# 6           551.0                73.0                      1266.0
# 11          506.0                77.0                      1088.0
# 16          620.0                81.0                      1334.0
# 21          412.0                91.0                      1238.0
#
#     playContinuedOutsideZoneAgainst  savedShotsOnGoalAgainst  \
# 1                            1294.0                   2361.0
# 6                            1492.0                   2494.0
# 11                           1304.0                   2169.0
# 16                           1378.0                   2439.0
# 21                           1304.0                   2266.0
#
#     savedUnblockedShotAttemptsAgainst  penalityMinutesAgainst  \
# 1                              3380.0                   919.0
# 6                              3585.0                  1123.0
# 11                             3135.0                  1007.0
# 16                             3596.0                  1008.0
# 21                             3197.0                   962.0
#
#     faceOffsWonAgainst  hitsAgainst  takeawaysAgainst  giveawaysAgainst  \
# 1               2426.0       1872.0             833.0             826.0
# 6               2363.0       1763.0             548.0             661.0
# 11              2424.0       1609.0             544.0             732.0
# 16              2507.0       1454.0             647.0             995.0
# 21              2234.0       1857.0             471.0             451.0
#
#     lowDangerShotsAgainst  mediumDangerShotsAgainst  highDangerShotsAgainst  \
# 1                  2678.0                     736.0                   224.0
# 6                  2887.0                     717.0                   224.0
# 11                 2605.0                     555.0                   178.0
# 16                 2862.0                     781.0                   231.0
# 21                 2670.0                     606.0                   170.0
#
#     lowDangerxGoalsAgainst  mediumDangerxGoalsAgainst  \
# 1                    78.52                      87.20
# 6                    92.36                      85.79
# 11                   74.06                      66.40
# 16                   85.49                      94.56
# 21                   75.62                      71.79
#
#     highDangerxGoalsAgainst  lowDangerGoalsAgainst  mediumDangerGoalsAgainst  \
# 1                     76.53                   92.0                      84.0
# 6                     81.00                   89.0                      76.0
# 11                    63.37                   69.0                      67.0
# 16                    82.22                   93.0                      99.0
# 21                    58.53                   87.0                      98.0
#
#     highDangerGoalsAgainst  scoreAdjustedShotsAttemptsAgainst  \
# 1                     82.0                            5040.57
# 6                     78.0                            4761.74
# 11                    67.0                            4369.88
# 16                    86.0                            5248.13
# 21                    64.0                            4507.18
#
#     unblockedShotAttemptsAgainst  scoreAdjustedUnblockedShotAttemptsAgainst  \
# 1                         3638.0                                    3650.78
# 6                         3828.0                                    3822.06
# 11                        3338.0                                    3319.17
# 16                        3874.0                                    3915.92
# 21                        3446.0                                    3462.98
#
#     dZoneGiveawaysAgainst  xGoalsFromxReboundsOfShotsAgainst  \
# 1                   398.0                              40.28
# 6                   326.0                              40.81
# 11                  425.0                              35.35
# 16                  591.0                              42.48
# 21                  216.0                              37.21
#
#     xGoalsFromActualReboundsOfShotsAgainst  reboundxGoalsAgainst  \
# 1                                    38.07                 40.25
# 6                                    45.50                 47.18
# 11                                   33.53                 36.27
# 16                                   40.21                 42.44
# 21                                   32.47                 33.21
#
#     totalShotCreditAgainst  scoreAdjustedTotalShotCreditAgainst  \
# 1                   242.28                               243.11
# 6                   243.46                               243.09
# 11                  200.22                               199.72
# 16                  260.04                               262.76
# 21                  209.94                               210.76
#
#     scoreFlurryAdjustedTotalShotCreditAgainst  playoff
# 1                                      235.81        0
# 6                                      235.24        0
# 11                                     194.82        0
# 16                                     255.33        0
# 21                                     206.71        0

# %%
df.to_csv("starting_data.csv", index=False)

# %%
train_df, test_df = train_test_split(df)

# %%
fig, axes = plt.subplots(nrows=len(train_df.columns.tolist()), ncols=1, figsize=(10, 3*len(train_df.columns.tolist())))

for i, c in enumerate(train_df.columns.tolist()):
    train_df.groupby("playoff")[c].plot.hist(
        bins=50,
        alpha=0.5, 
        legend=True, 
        density=True, 
        ax=axes[i]
    )
    
    axes[i].set_title(f"Histogram of {c}")
    axes[i].set_xlabel(c)

plt.tight_layout()
plt.show()

# %%
v2_cols_to_del = ["iceTime",
                   "reboundsFor",
                   "reboundGoalsFor",
                   "playStoppedFor",
                   "playContinuedOutsideZoneFor",
                   "penalityMinutesFor",
                   "faceOffsWonFor",
                   "hitsFor",
                   "takeawaysFor",
                   "giveawaysFor",
                   "highDangerShotsFor",
                   "highDangerxGoalsFor",
                   "dZoneGiveawaysFor",
                   "xGoalsFromActualReboundsOfShotsFor",
                   "reboundxGoalsFor",
                   "blockedShotAttemptsAgainst",
                   "reboundsAgainst",
                   "reboundGoalsAgainst",
                   "freezeAgainst",
                   "playStoppedAgainst",
                   "penalityMinutesAgainst",
                   "faceOffsWonAgainst",
                   "hitsAgainst",
		           "takeawaysAgainst",
                   "giveawaysAgainst",
                   "highDangerShotsAgainst",
                   "highDangerxGoalsAgainst",
                   "dZoneGiveawaysAgainst",
                   "xGoalsFromxReboundsOfShotsAgainst",
                   "xGoalsFromActualReboundsOfShotsAgainst",
                   "reboundxGoalsAgainst"]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316 entries, 1391 to 156
# Data columns (total 99 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   xGoalsPercentage                           316 non-null    float64
#  1   corsiPercentage                            316 non-null    float64
#  2   fenwickPercentage                          316 non-null    float64
#  3   iceTime                                    316 non-null    float64
#  4   xOnGoalFor                                 316 non-null    float64
#  5   xGoalsFor                                  316 non-null    float64
#  6   xReboundsFor                               316 non-null    float64
#  7   xFreezeFor                                 316 non-null    float64
#  8   xPlayStoppedFor                            316 non-null    float64
#  9   xPlayContinuedInZoneFor                    316 non-null    float64
#  10  xPlayContinuedOutsideZoneFor               316 non-null    float64
#  11  flurryAdjustedxGoalsFor                    316 non-null    float64
#  12  scoreVenueAdjustedxGoalsFor                316 non-null    float64
#  13  flurryScoreVenueAdjustedxGoalsFor          316 non-null    float64
#  14  shotsOnGoalFor                             316 non-null    float64
#  15  missedShotsFor                             316 non-null    float64
#  16  blockedShotAttemptsFor                     316 non-null    float64
#  17  shotAttemptsFor                            316 non-null    float64
#  18  goalsFor                                   316 non-null    float64
#  19  reboundsFor                                316 non-null    float64
#  20  reboundGoalsFor                            316 non-null    float64
#  21  freezeFor                                  316 non-null    float64
#  22  playStoppedFor                             316 non-null    float64
#  23  playContinuedInZoneFor                     316 non-null    float64
#  24  playContinuedOutsideZoneFor                316 non-null    float64
#  25  savedShotsOnGoalFor                        316 non-null    float64
#  26  savedUnblockedShotAttemptsFor              316 non-null    float64
#  27  penalityMinutesFor                         316 non-null    float64
#  28  faceOffsWonFor                             316 non-null    float64
#  29  hitsFor                                    316 non-null    float64
#  30  takeawaysFor                               316 non-null    float64
#  31  giveawaysFor                               316 non-null    float64
#  32  lowDangerShotsFor                          316 non-null    float64
#  33  mediumDangerShotsFor                       316 non-null    float64
#  34  highDangerShotsFor                         316 non-null    float64
#  35  lowDangerxGoalsFor                         316 non-null    float64
#  36  mediumDangerxGoalsFor                      316 non-null    float64
#  37  highDangerxGoalsFor                        316 non-null    float64
#  38  lowDangerGoalsFor                          316 non-null    float64
#  39  mediumDangerGoalsFor                       316 non-null    float64
#  40  highDangerGoalsFor                         316 non-null    float64
#  41  scoreAdjustedShotsAttemptsFor              316 non-null    float64
#  42  unblockedShotAttemptsFor                   316 non-null    float64
#  43  scoreAdjustedUnblockedShotAttemptsFor      316 non-null    float64
#  44  dZoneGiveawaysFor                          316 non-null    float64
#  45  xGoalsFromxReboundsOfShotsFor              316 non-null    float64
#  46  xGoalsFromActualReboundsOfShotsFor         316 non-null    float64
#  47  reboundxGoalsFor                           316 non-null    float64
#  48  totalShotCreditFor                         316 non-null    float64
#  49  scoreAdjustedTotalShotCreditFor            316 non-null    float64
#  50  scoreFlurryAdjustedTotalShotCreditFor      316 non-null    float64
#  51  xOnGoalAgainst                             316 non-null    float64
#  52  xGoalsAgainst                              316 non-null    float64
#  53  xReboundsAgainst                           316 non-null    float64
#  54  xFreezeAgainst                             316 non-null    float64
#  55  xPlayStoppedAgainst                        316 non-null    float64
#  56  xPlayContinuedInZoneAgainst                316 non-null    float64
#  57  xPlayContinuedOutsideZoneAgainst           316 non-null    float64
#  58  flurryAdjustedxGoalsAgainst                316 non-null    float64
#  59  scoreVenueAdjustedxGoalsAgainst            316 non-null    float64
#  60  flurryScoreVenueAdjustedxGoalsAgainst      316 non-null    float64
#  61  shotsOnGoalAgainst                         316 non-null    float64
#  62  missedShotsAgainst                         316 non-null    float64
#  63  blockedShotAttemptsAgainst                 316 non-null    float64
#  64  shotAttemptsAgainst                        316 non-null    float64
#  65  goalsAgainst                               316 non-null    float64
#  66  reboundsAgainst                            316 non-null    float64
#  67  reboundGoalsAgainst                        316 non-null    float64
#  68  freezeAgainst                              316 non-null    float64
#  69  playStoppedAgainst                         316 non-null    float64
#  70  playContinuedInZoneAgainst                 316 non-null    float64
#  71  playContinuedOutsideZoneAgainst            316 non-null    float64
#  72  savedShotsOnGoalAgainst                    316 non-null    float64
#  73  savedUnblockedShotAttemptsAgainst          316 non-null    float64
#  74  penalityMinutesAgainst                     316 non-null    float64
#  75  faceOffsWonAgainst                         316 non-null    float64
#  76  hitsAgainst                                316 non-null    float64
#  77  takeawaysAgainst                           316 non-null    float64
#  78  giveawaysAgainst                           316 non-null    float64
#  79  lowDangerShotsAgainst                      316 non-null    float64
#  80  mediumDangerShotsAgainst                   316 non-null    float64
#  81  highDangerShotsAgainst                     316 non-null    float64
#  82  lowDangerxGoalsAgainst                     316 non-null    float64
#  83  mediumDangerxGoalsAgainst                  316 non-null    float64
#  84  highDangerxGoalsAgainst                    316 non-null    float64
#  85  lowDangerGoalsAgainst                      316 non-null    float64
#  86  mediumDangerGoalsAgainst                   316 non-null    float64
#  87  highDangerGoalsAgainst                     316 non-null    float64
#  88  scoreAdjustedShotsAttemptsAgainst          316 non-null    float64
#  89  unblockedShotAttemptsAgainst               316 non-null    float64
#  90  scoreAdjustedUnblockedShotAttemptsAgainst  316 non-null    float64
#  91  dZoneGiveawaysAgainst                      316 non-null    float64
#  92  xGoalsFromxReboundsOfShotsAgainst          316 non-null    float64
#  93  xGoalsFromActualReboundsOfShotsAgainst     316 non-null    float64
#  94  reboundxGoalsAgainst                       316 non-null    float64
#  95  totalShotCreditAgainst                     316 non-null    float64
#  96  scoreAdjustedTotalShotCreditAgainst        316 non-null    float64
#  97  scoreFlurryAdjustedTotalShotCreditAgainst  316 non-null    float64
#  98  playoff                                    316 non-null    int64
# dtypes: float64(98), int64(1)
# memory usage: 246.9 KB

# %%
cols = train_df.columns.tolist()
print(len(cols))
cols = [c for c in cols if c not in v2_cols_to_del]
print(len(cols))
print(len(v2_cols_to_del))
# Out:
# 99
# 68
# 31

# %%
X_train = train_df[cols]
X_train = X_train.drop(columns=["playoff"])
y_train = train_df.loc[:, "playoff"]

X_test = test_df[cols]
X_test = X_test.drop(columns=["playoff"])
y_test = test_df.loc[:, "playoff"]

# %%
dummy = DummyClassifier()
dummy_df = pd.DataFrame(cross_validate(dummy, X_train, y_train, cv=5, return_train_score=True))
dummy_df
# Out:
#    fit_time  score_time  test_score  train_score
# 0  0.001252    0.000574    0.515625     0.511905
# 1  0.000559    0.000486    0.507937     0.513834
# 2  0.000451    0.000400    0.507937     0.513834
# 3  0.000955    0.000698    0.507937     0.513834
# 4  0.000442    0.000397    0.523810     0.509881

# %%
X_train.isna().any().any()
# Out:
# np.False_

# %%
numeric_transformer = StandardScaler()

# %%
len(cols)==X_train.shape[1]==X_test.shape[1]
# Out:
# False

# %%
cols.remove("playoff")
len(cols)==X_train.shape[1]==X_test.shape[1]
# Out:
# True

# %%
len(cols)==X_train.shape[1]==X_test.shape[1]
# Out:
# True

# %%
preprocessor = make_column_transformer(
    (
        numeric_transformer,
        cols
    )
)

# %%
models = {
    "decision_tree": DecisionTreeClassifier(),
    "knn": KNeighborsClassifier(),
    "rbf_svm": SVC(),
    "lr": LogisticRegression()
}

# %%
results = {}

for name, model in models.items():
    pipe = make_pipeline(preprocessor, model)
    cv = cross_validate(pipe, X_train, y_train, return_train_score=True)
    
    result_dict = {}
    result_dict["train_mean"] = cv["train_score"].mean()
    for i, score in enumerate(cv["train_score"]):
        result_dict[f"train_fold{i+1}"] = score
    
    result_dict["test_mean"] = cv["test_score"].mean()
    
    for i, score in enumerate(cv["test_score"]):
        result_dict[f"test_fold{i+1}"] = score
    
    results[name] = result_dict
    
results_df = pd.DataFrame(results).T
results_df.sort_values("test_mean", ascending=False)
# Out:
#                train_mean  train_fold1  train_fold2  train_fold3  train_fold4  \
# lr               0.944614     0.936508     0.944664     0.948617     0.948617
# rbf_svm          0.935131     0.940476     0.936759     0.924901     0.936759
# decision_tree    1.000000     1.000000     1.000000     1.000000     1.000000
# knn              0.880535     0.876984     0.869565     0.877470     0.889328
#
#                train_fold5  test_mean  test_fold1  test_fold2  test_fold3  \
# lr                0.944664   0.914633    0.890625    0.888889    0.920635
# rbf_svm           0.936759   0.873661    0.796875    0.888889    0.904762
# decision_tree     1.000000   0.819792    0.765625    0.841270    0.888889
# knn               0.889328   0.813542    0.734375    0.857143    0.888889
#
#                test_fold4  test_fold5
# lr               0.952381    0.920635
# rbf_svm          0.888889    0.888889
# decision_tree    0.809524    0.793651
# knn              0.793651    0.793651

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Bar chart
x = range(len(results_df))
width = 0.35
ax1.bar([i - width/2 for i in x], results_df['train_mean'], width, label='Train Mean', alpha=0.8)
ax1.bar([i + width/2 for i in x], results_df['test_mean'], width, label='Test Mean', alpha=0.8)
ax1.set_xlabel('Model')
ax1.set_ylabel('Score')
ax1.set_title('Bar Chart')
ax1.set_xticks(x)
ax1.set_xticklabels(results_df.index)
ax1.legend()
ax1.grid(axis='y', alpha=0.3)

# Line chart
ax2.plot(results_df.index, results_df['train_mean'], marker='o', linewidth=2, markersize=8, label='Train Mean')
ax2.plot(results_df.index, results_df['test_mean'], marker='o', linewidth=2, markersize=8, label='Test Mean')
ax2.set_xlabel('Model')
ax2.set_ylabel('Score')
ax2.set_title('Line Chart')
ax2.legend()
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
test_pipe = make_pipeline(preprocessor, LogisticRegression())

test_pipe.fit(X_train, y_train)
test_score = test_pipe.score(X_test, y_test)

# %%
test_score
# Out:
# 0.8867924528301887

# %%
param_grid_dt = {
    "decisiontreeclassifier__max_depth": np.arange(3, 31)
}
pipe_dt = make_pipeline(preprocessor, DecisionTreeClassifier())
grid_search_dt = GridSearchCV(pipe_dt, param_grid_dt, verbose=1, n_jobs=-1,) #grid search because small search space
grid_search_dt.fit(X_train, y_train)
pd.DataFrame(grid_search_dt.cv_results_)[["mean_test_score", "param_decisiontreeclassifier__max_depth", "mean_fit_time", "rank_test_score"]].set_index("rank_test_score").sort_index()
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
#                  mean_test_score  param_decisiontreeclassifier__max_depth  \
# rank_test_score
# 1                       0.841915                                        3
# 2                       0.835565                                       17
# 3                       0.835516                                        8
# 4                       0.829365                                       23
# 5                       0.829315                                       19
# 6                       0.826240                                       11
# 7                       0.826141                                        4
# 8                       0.826091                                       12
# 8                       0.826091                                       28
# 8                       0.826091                                       24
# 11                      0.823065                                       20
# 12                      0.819792                                       18
# 13                      0.819742                                       25
# 14                      0.819692                                        5
# 15                      0.816716                                       30
# 16                      0.816617                                       15
# 17                      0.816518                                        6
# 18                      0.813492                                       10
# 19                      0.813442                                       27
# 19                      0.813442                                       21
# 19                      0.813442                                       22
# 22                      0.813393                                       29
# 23                      0.810367                                       13
# 24                      0.803919                                       14
# 25                      0.803869                                       26
# 26                      0.800794                                        7
# 27                      0.797669                                       16
# 28                      0.797569                                        9
#
#                  mean_fit_time
# rank_test_score
# 1                     0.007429
# 2                     0.010491
# 3                     0.016639
# 4                     0.011659
# 5                     0.010439
# 6                     0.016167
# 7                     0.009796
# 8                     0.009567
# 8                     0.012313
# 8                     0.013150
# 11                    0.010015
# 12                    0.011585
# 13                    0.012283
# 14                    0.010981
# 15                    0.010835
# 16                    0.011500
# 17                    0.008901
# 18                    0.011025
# 19                    0.012783
# 19                    0.011949
# 19                    0.011320
# 22                    0.011655
# 23                    0.009815
# 24                    0.011014
# 25                    0.015212
# 26                    0.011124
# 27                    0.010392
# 28                    0.017515

# %%
param_grid_knn = {
    "kneighborsclassifier__n_neighbors": np.arange(3, 31) #grid search because small search space
}
pipe_knn = make_pipeline(preprocessor, KNeighborsClassifier())
grid_search_knn = GridSearchCV(pipe_knn, param_grid_knn, verbose=1, n_jobs=-1) #grid search because small search space
grid_search_knn.fit(X_train, y_train)
pd.DataFrame(grid_search_knn.cv_results_)[["mean_test_score", "param_kneighborsclassifier__n_neighbors", "mean_fit_time", "rank_test_score"]].set_index("rank_test_score").sort_index()
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
#                  mean_test_score  param_kneighborsclassifier__n_neighbors  \
# rank_test_score
# 1                       0.826190                                       16
# 2                       0.823065                                       29
# 3                       0.822966                                       17
# 4                       0.819891                                       15
# 5                       0.816766                                       28
# 6                       0.816716                                       14
# 7                       0.816716                                       12
# 7                       0.816716                                       30
# 9                       0.813641                                       24
# 10                      0.813542                                        5
# 10                      0.813542                                       13
# 10                      0.813542                                       19
# 13                      0.810417                                       27
# 13                      0.810417                                       18
# 15                      0.810417                                       21
# 15                      0.810417                                       25
# 17                      0.807292                                       26
# 18                      0.807093                                       11
# 19                      0.804117                                       20
# 20                      0.804067                                       23
# 21                      0.800893                                        8
# 22                      0.800843                                        3
# 23                      0.797768                                       22
# 24                      0.797718                                        7
# 25                      0.797669                                        6
# 26                      0.791369                                        9
# 27                      0.788244                                        4
# 28                      0.788145                                       10
#
#                  mean_fit_time
# rank_test_score
# 1                     0.006826
# 2                     0.004582
# 3                     0.006043
# 4                     0.005061
# 5                     0.004740
# 6                     0.003368
# 7                     0.006425
# 7                     0.004020
# 9                     0.003764
# 10                    0.006326
# 10                    0.004499
# 10                    0.003986
# 13                    0.005972
# 13                    0.005470
# 15                    0.004990
# 15                    0.004684
# 17                    0.004619
# 18                    0.004142
# 19                    0.004137
# 20                    0.005083
# 21                    0.004892
# 22                    0.004739
# 23                    0.005192
# 24                    0.009449
# 25                    0.003402
# 26                    0.009791
# 27                    0.004711
# 28                    0.005781

# %%
param_grid_svc = {
    "svc__C": loguniform(1e-2, 1e3),
    "svc__gamma": loguniform(1e-4, 1e1)
}
pipe_svc = make_pipeline(preprocessor, SVC())
random_search_svc = RandomizedSearchCV(pipe_svc, param_grid_svc, n_iter=30, verbose=1, n_jobs=-1)
random_search_svc.fit(X_train, y_train)
pd.DataFrame(random_search_svc.cv_results_)[["mean_test_score", "param_svc__C", "param_svc__gamma", "mean_fit_time", "rank_test_score"]].set_index("rank_test_score").sort_index()
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#                  mean_test_score  param_svc__C  param_svc__gamma  \
# rank_test_score
# 1                       0.911458     35.501302          0.003097
# 2                       0.905109     85.388676          0.000141
# 3                       0.902083     14.722479          0.000908
# 4                       0.882986      6.497749          0.019066
# 5                       0.873611     10.863230          0.000163
# 6                       0.873512    554.842372          0.001623
# 7                       0.870337    134.734407          0.020898
# 8                       0.867163     70.296432          0.006266
# 9                       0.863988     62.525908          0.016543
# 10                      0.854514     20.902283          0.035810
# 10                      0.854514     23.688019          0.036237
# 12                      0.854464    173.675552          0.046571
# 13                      0.842063      0.451953          0.004096
# 14                      0.816518      5.660331          0.115796
# 15                      0.788343      1.456656          0.000177
# 16                      0.778720      0.581460          0.000275
# 17                      0.756448      0.121103          0.000857
# 18                      0.756300    497.085560          0.210648
# 19                      0.753274      0.376686          0.000219
# 20                      0.737302    419.010866          0.223293
# 21                      0.718353      0.030005          0.012887
# 22                      0.512649    367.255345          2.708366
# 22                      0.512649     13.890365          8.620797
# 22                      0.512649     16.905245          1.189105
# 22                      0.512649      0.251835          2.029107
# 22                      0.512649     33.707217          3.477898
# 22                      0.512649      7.610420          1.585951
# 22                      0.512649     17.260312          2.482587
# 22                      0.512649      0.131037          0.149988
# 22                      0.512649      5.645678          0.885368
#
#                  mean_fit_time
# rank_test_score
# 1                     0.006446
# 2                     0.005728
# 3                     0.008556
# 4                     0.008085
# 5                     0.006482
# 6                     0.006918
# 7                     0.007071
# 8                     0.006302
# 9                     0.006205
# 10                    0.008091
# 10                    0.007176
# 12                    0.007153
# 13                    0.006602
# 14                    0.007041
# 15                    0.005115
# 16                    0.007932
# 17                    0.007374
# 18                    0.007820
# 19                    0.006039
# 20                    0.006907
# 21                    0.008493
# 22                    0.009600
# 22                    0.010736
# 22                    0.008168
# 22                    0.007298
# 22                    0.008296
# 22                    0.009324
# 22                    0.007772
# 22                    0.008587
# 22                    0.007588

# %%
param_grid_lr = {
    "logisticregression__C": loguniform(1e-3, 1e3)
}
pipe_lr = make_pipeline(preprocessor, LogisticRegression())
random_search_lr = RandomizedSearchCV(pipe_lr, param_grid_lr, n_iter=30, verbose=1, n_jobs=-1) 
random_search_lr.fit(X_train, y_train)
pd.DataFrame(random_search_lr.cv_results_)[["mean_test_score", "param_logisticregression__C", "mean_fit_time", "rank_test_score"]].set_index("rank_test_score").sort_index()
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#                  mean_test_score  param_logisticregression__C  mean_fit_time
# rank_test_score
# 1                       0.917857                     0.220907       0.007621
# 1                       0.917857                     0.229597       0.007235
# 1                       0.917857                     0.191938       0.012809
# 4                       0.914683                     0.415941       0.008742
# 4                       0.914683                     0.430491       0.017801
# 4                       0.914683                     0.094585       0.010192
# 4                       0.914683                     0.122932       0.008943
# 8                       0.914633                     0.937519       0.014823
# 9                       0.911508                     0.163560       0.007106
# 10                      0.908284                     2.817965       0.009779
# 10                      0.908284                     1.583670       0.010149
# 12                      0.901984                     3.322286       0.009319
# 13                      0.901935                     4.726132       0.011894
# 14                      0.898909                     0.035951       0.007454
# 14                      0.898909                     0.035420       0.007005
# 16                      0.898760                     7.725038       0.030780
# 17                      0.892411                    14.145108       0.024945
# 18                      0.889484                     0.019129       0.006598
# 19                      0.889286                    30.130534       0.017044
# 20                      0.867163                    87.882699       0.025350
# 21                      0.864038                   180.557359       0.018211
# 22                      0.860913                   410.719833       0.015163
# 23                      0.857639                   134.554609       0.017737
# 24                      0.854563                     0.011061       0.006214
# 25                      0.854514                   913.797604       0.033337
# 26                      0.832688                     0.004586       0.016440
# 27                      0.829613                     0.002651       0.008561
# 28                      0.823313                     0.002339       0.006758
# 29                      0.810615                     0.001863       0.006186
# 30                      0.804315                     0.001411       0.009955

# %%
best_C = 220907

# %%
pipe_final = make_pipeline(preprocessor, LogisticRegression(C=best_C, max_iter=1000)) # best model based on hyperparameter optimization, max_iter=1000 to avoid warning
pipe_final.fit(X_train, y_train)
test_score_final = pipe_final.score(X_test, y_test)

# %%
test_score_final
# Out:
# 0.8679245283018868

# %% [markdown]
# this is worse than our logistic regression with no hyp opt... overfit, small dataset...
